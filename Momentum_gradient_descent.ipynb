# %% [markdown]
# <a href="https://colab.research.google.com/github/Revathi0828/Deep_Learning/blob/main/Momentum_gradient_descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

X=np.array([2,3,4,5])
y=np.array([4,6,8,10])

b0=0.0
b1=0.0

v0=0.0
v1=0.0

beta=0.9

n=len(y)
n_iter=260
learn_rate=0.1

loss_hist=[]

for j in range(n_iter):

    db0=0.0
    db1=0.0

    y_pred=np.zeros(n)

    for i in range(n):

        y_pred[i] = b0 + b1*X[i]

        error = y_pred[i] - y[i]

        db0 += (1/n)*error
        db1 += (1/n)*error*X[i]

    v0 = beta*v0 + learn_rate*db0
    v1 = beta*v1 + learn_rate*db1

    b0 -= v0
    b1 -= v1

    loss = np.sum((y_pred-y)**2)/(2*n)
    loss_hist.append(loss)

    if (j %100 < 5 or j < 5):
        print(f"loss {loss:.6f}")
        print(f"b0 {b0:.6f} b1 {b1:.6f}")

plt.figure(figsize=(8,3))

plt.subplot(1,2,1)
plt.scatter(X,y,label='Data')
plt.plot(X,y_pred,'r-',label=f'Fit y={b1:.2f}X+{b0:.2f}')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title("Momentum GD")

plt.subplot(1,2,2)
plt.plot(loss_hist[:100],'g-',label='Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title("Loss Convergence")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# loss 27.000000
# b0 0.700000 b1 2.700000
# loss 5.267500
# b0 1.015000 b1 3.940000
# loss 32.811263
# b0 0.518000 b1 2.081750
# loss 0.327485
# b0 -0.009712 b1 0.117662
# loss 23.980598
# b0 0.175136 b1 0.894539
# loss 0.000054
# b0 0.003559 b1 2.009866
# loss 0.000786
# b0 0.002506 b1 2.006852
# loss 0.000380
# b0 -0.001090 b1 1.994012
# loss 0.000265
# b0 -0.002122 b1 1.990922
# loss 0.000626
# b0 0.000339 b1 2.001139
# loss 0.000000
# b0 0.000001 b1 2.000060
# loss 0.000000
# b0 -0.000014 b1 2.000003
# loss 0.000000
# b0 -0.000026 b1 1.999952
# loss 0.000000
# b0 -0.000018 b1 1.999980
# loss 0.000000
# b0 -0.000002 b1 2.000038
